# %%
import utils.plotting

# %%
num_syns = 50
syn_type = 'basal'

sim_dir = f'/home/kedoxey/PyramidalCellSimulations/models/NEURON/NMLCL000073-NEURON/output/EAP_{syn_type}/EAP_{syn_type}-0nA-{num_syns}Ex1-1x40Hz-100x64elec-probes_dl'
sim_label = f'EAP_{syn_type}-0nA-{num_syns}Ex1-1x40Hz-100x64elec-probes_dl'

type_probes = 'closest'

utils.plotting.plot_eap_kernel(type_probes, sim_dir, sim_label)

type_probes = 'farthest'

utils.plotting.plot_eap_kernel(type_probes, sim_dir, sim_label)
# Out:
# Closest probe found at 11.84233265580536 microns...
# Closest probe found at 11.84233265580536 microns...
# Closest probe found at 11.84233265580536 microns...
# Farthest probe found at 64.58923536080255 microns...

# %%
# Out:
# Closest probe found at 10.41616376956805 microns...
# Farthest probe found at 64.44192285695377 microns...
