# %%
import matplotlib
import os
import json
# %matplotlib inline

# %% [markdown]
# ### Define model

# %%
model = 'L5bPyrCellHayEtAl2011'

# %% [markdown]
# ### Define directories

# %%
cwd = os.getcwd()
model_dir = os.path.join(cwd, model)
neuron_dir = os.path.join(model_dir, 'NEURON')
mod_dir = os.path.join(neuron_dir, 'mod')
models_dir = os.path.join(neuron_dir, 'models')

# %% [markdown]
# ### Compile Mechanisms

# %%
os.chdir(mod_dir)
os.system('nrnivmodl .')
os.chdir(cwd)
# Out:
# /usr/bin/xcrun
# /Users/katedoxey/Desktop/research/Projects/CRCNS/code/PyramidalCellSimulations/L5bPyrCellHayEtAl2011/NEURON/mod
# Mod files: "././CaDynamics_E2.mod" "././Ca_HVA.mod" "././Ca_LVAst.mod" "././Ih.mod" "././Im.mod" "././K_Pst.mod" "././K_Tst.mod" "././NaTa_t.mod" "././NaTs2_t.mod" "././Nap_Et2.mod" "././SK_E2.mod" "././SKv3_1.mod" "././epsp.mod"
#
# Creating 'arm64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL .././CaDynamics_E2.mod
#  -> NMODL .././Ca_HVA.mod
#  -> NMODL .././Ca_LVAst.mod
#  -> NMODL .././Ih.mod
#  -> NMODL .././Im.mod
#  -> NMODL .././K_Pst.mod
#  -> NMODL .././K_Tst.mod
#  -> NMODL .././NaTa_t.mod
#  -> NMODL .././NaTs2_t.mod
#  -> NMODL .././Nap_Et2.mod
#  -> NMODL .././SK_E2.mod
#  -> NMODL .././SKv3_1.mod
#  -> Compiling Ca_HVA.c
#  -> NMODL .././epsp.mod
#  -> Compiling CaDynamics_E2.c
#  -> Compiling Ca_LVAst.c
# Translating Ca_HVA.mod into /Users/katedoxey/Desktop/research/Projects/CRCNS/code/PyramidalCellSimulations/L5bPyrCellHayEtAl2011/NEURON/mod/arm64/Ca_HVA.c
# Translating Ca_LVAst.mod into /Users/katedoxey/Desktop/research/Projects/CRCNS/code/PyramidalCellSimulations/L5bPyrCellHayEtAl2011/NEURON/mod/arm64/Ca_LVAst.c
# Translating CaDynamics_E2.mod into /Users/katedoxey/Desktop/research/Projects/CRCNS/code/PyramidalCellSimulations/L5bPyrCellHayEtAl2011/NEURON/mod/arm64/CaDynamics_E2.c
# Thread Safe
# Thread Safe
# Thread Safe
# Translating Im.mod into /Users/katedoxey/Desktop/research/Projects/CRCNS/code/PyramidalCellSimulations/L5bPyrCellHayEtAl2011/NEURON/mod/arm64/Im.c
# Translating Ih.mod into /Users/katedoxey/Desktop/research/Projects/CRCNS/code/PyramidalCellSimulations/L5bPyrCellHayEtAl2011/NEURON/mod/arm64/Ih.c
# Translating K_Pst.mod into /Users/katedoxey/Desktop/research/Projects/CRCNS/code/PyramidalCellSimulations/L5bPyrCellHayEtAl2011/NEURON/mod/arm64/K_Pst.c
# Thread Safe
# Thread Safe
# Thread Safe
# Translating NaTa_t.mod into /Users/katedoxey/Desktop/research/Projects/CRCNS/code/PyramidalCellSimulations/L5bPyrCellHayEtAl2011/NEURON/mod/arm64/NaTa_t.c
# Translating K_Tst.mod into /Users/katedoxey/Desktop/research/Projects/CRCNS/code/PyramidalCellSimulations/L5bPyrCellHayEtAl2011/NEURON/mod/arm64/K_Tst.c
# Translating NaTs2_t.mod into /Users/katedoxey/Desktop/research/Projects/CRCNS/code/PyramidalCellSimulations/L5bPyrCellHayEtAl2011/NEURON/mod/arm64/NaTs2_t.c
# Thread Safe
# Thread Safe
# Thread Safe
# Translating Nap_Et2.mod into /Users/katedoxey/Desktop/research/Projects/CRCNS/code/PyramidalCellSimulations/L5bPyrCellHayEtAl2011/NEURON/mod/arm64/Nap_Et2.c
# Translating SKv3_1.mod into /Users/katedoxey/Desktop/research/Projects/CRCNS/code/PyramidalCellSimulations/L5bPyrCellHayEtAl2011/NEURON/mod/arm64/SKv3_1.c
# Translating SK_E2.mod into /Users/katedoxey/Desktop/research/Projects/CRCNS/code/PyramidalCellSimulations/L5bPyrCellHayEtAl2011/NEURON/mod/arm64/SK_E2.c
# Thread Safe
# Thread Safe
# Thread Safe
# Translating epsp.mod into /Users/katedoxey/Desktop/research/Projects/CRCNS/code/PyramidalCellSimulations/L5bPyrCellHayEtAl2011/NEURON/mod/arm64/epsp.c
# Thread Safe
# Ca_HVA.c:284:15: warning: equality comparison with extraneous parentheses [-Wparentheses-equality]
#     if ( ( v  == - 27.0 ) ) {
#            ~~~^~~~~~~~~
# Ca_HVA.c:284:15: note: remove extraneous parentheses around the comparison to silence this warning
#     if ( ( v  == - 27.0 ) ) {
#          ~~   ^         ~~
# Ca_HVA.c:284:15: note: use '=' to turn this equality comparison into an assignment
#     if ( ( v  == - 27.0 ) ) {
#               ^~
#               =
# 1 warning generated.
#  -> Compiling Ih.c
#  -> Compiling Im.c
#  -> Compiling K_Pst.c
#  -> Compiling K_Tst.c
#  -> Compiling NaTs2_t.c
#  -> Compiling NaTa_t.c
#  -> Compiling Nap_Et2.c
#  -> Compiling SK_E2.c
#  -> Compiling SKv3_1.c
#  -> Compiling epsp.c
#  => LINKING shared library ./libnrnmech.dylib
#  => LINKING executable ./special LDFLAGS are:
# Successfully created arm64/special

# %% [markdown]
# ### Import cell into NetPyNE

# %%
from netpyne import specs, sim

# Network parameters
netParams = specs.NetParams()
# Out:
# Warning: no DISPLAY environment variable.
# --No graphics will be displayed.

# %% [markdown]
# L5CPbiophys1

# %%
netParams.importCellParams(
    label='L5PCbiophys1_hoc',
    conds={'cellType': 'PYR', 'cellModel': 'Hay2011'},
    fileName=f'{models_dir}/L5PCbiophys1.hoc',
    cellName='L5PCbiophys',
    importSynMechs=False
)
# Out:
# NEURON: Ca_LVAst is not a MECHANISM
#  in L5PCbiophys1.hoc near line 20
#  	  insert Ca_LVAst
#                   ^
#         xopen("L5PCbiophy...")
#       execute1("{xopen("L5...")
#     load_file("/Users/kat..."
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
