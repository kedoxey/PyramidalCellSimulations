# %%
import matplotlib
import os
import json
import model_helpers as mh
from pyneuroml import pynml
from pyneuroml.analysis import generate_current_vs_frequency_curve
# %matplotlib inline

# %%
nmldb_id = "NMLCL000073"
model_source = 'NeuroML'
model_name = "L5PC"

# %%
cwd = os.getcwd()
models_dir = os.path.join(cwd, 'models')
model_dir = os.path.join(models_dir, model_source, nmldb_id)

# %%
mh.download_from_nmldb(nmldb_id, model_source)
# Out:
# Model NMLCL000073 already downloaded.

# %%
cell_fname = os.path.join(model_dir,model_name) + '.cell.nml'
cell_fname
# Out:
# '/home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/L5PC.cell.nml'

# %%
cell_nml = pynml.read_neuroml2_file(cell_fname)
# Out:
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/L5PC.cell.nml

# %%
na_erev = 50

generate_current_vs_frequency_curve('models/NeuroML/NMLCL000073/L5PC.cell.nml',
                                    cell_nml.id,
                                    start_amp_nA=-0.02,
                                    end_amp_nA=0.06,
                                    step_nA=0.01,
                                    pre_zero_pulse=20,
                                    post_zero_pulse=20,
                                    analysis_duration=100,
                                    temperature='34degC',
                                    plot_voltage_traces=True)
# Out:
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/L5PC.cell.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/Ca_HVA.channel.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/Ca_LVAst.channel.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/CaDynamics_E2_NML2__decay122__gamma5_09Emin4.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/CaDynamics_E2_NML2__decay460__gamma5_01Emin4.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/Ih.channel.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/Im.channel.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/K_Pst.channel.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/K_Tst.channel.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/Nap_Et2.channel.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/NaTa_t.channel.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/pas.channel.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/SK_E2.channel.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/SKv3_1.channel.nml
# pyNeuroML >>> INFO - Executing: (java -Xmx400M  -jar  "/home/kedoxey/.conda/envs/OBModel_linux/lib/python3.7/site-packages/pyneuroml/lib/jNeuroML-0.12.0-jar-with-dependencies.jar" -validate "iv_L5PC.net.nml" ) in directory: .
# pyNeuroML >>> INFO - Command completed. Output:
#   jNeuroML >>   jNeuroML v0.12.0
#   jNeuroML >>  Validating: /home/kedoxey/CRCNS/PyramidalCellSimulations/iv_L5PC.net.nml
#   jNeuroML >>  Valid against schema and all tests
#   jNeuroML >>  No warnings
#   jNeuroML >>
#   jNeuroML >>  Validated 1 files: All valid and no warnings
#   jNeuroML >>
#   jNeuroML >>
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/iv_L5PC.net.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/L5PC.cell.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/Ca_HVA.channel.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/Ca_LVAst.channel.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/CaDynamics_E2_NML2__decay122__gamma5_09Emin4.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/CaDynamics_E2_NML2__decay460__gamma5_01Emin4.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/Ih.channel.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/Im.channel.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/K_Pst.channel.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/K_Tst.channel.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/Nap_Et2.channel.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/NaTa_t.channel.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/pas.channel.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/SK_E2.channel.nml
# pyNeuroML >>> INFO - Loading NeuroML2 file: /home/kedoxey/CRCNS/PyramidalCellSimulations/models/NeuroML/NMLCL000073/SKv3_1.channel.nml
# pyNeuroML >>> INFO - Loading LEMS file: LEMS_iv_L5PC.xml and running with jNeuroML
# pyNeuroML >>> INFO - Executing: (java -Xmx400M  -Djava.awt.headless=true -jar  "/home/kedoxey/.conda/envs/OBModel_linux/lib/python3.7/site-packages/pyneuroml/lib/jNeuroML-0.12.0-jar-with-dependencies.jar"  "LEMS_iv_L5PC.xml"  -nogui -I '') in directory: .
# pyNeuroML >>> CRITICAL - *** Problem running command:
#        Command 'java -Xmx400M  -Djava.awt.headless=true -jar  "/home/kedoxey/.conda/envs/OBModel_linux/lib/python3.7/site-packages/pyneuroml/lib/jNeuroML-0.12.0-jar-with-dependencies.jar"  "LEMS_iv_L5PC.xml"  -nogui -I ''' returned non-zero exit status 1.
# pyNeuroML >>> CRITICAL -  jNeuroML >>   jNeuroML v0.12.0
#  jNeuroML >>  Loading: /home/kedoxey/CRCNS/PyramidalCellSimulations/LEMS_iv_L5PC.xml with jLEMS, NO GUI mode...
#  jNeuroML >>  org.neuroml.export.exceptions.ModelFeatureSupportException: Feature not supported in LEMS: MULTICOMPARTMENTAL_CELL_MODEL (Model with multicompartmental cell(s))
#  jNeuroML >>      Level of support for MULTICOMPARTMENTAL_CELL_MODEL in LEMS is insufficient: NONE
#  jNeuroML >>
#  jNeuroML >>  Info on supported features:
#  jNeuroML >>  Format: LEMS
#  jNeuroML >>      ✓ SINGLE_COMP_MODEL (Model with only a single component (no network)): HIGH
#  jNeuroML >>      ✓ NETWORK_MODEL (Network model): HIGH
#  jNeuroML >>      ✓ MULTI_CELL_MODEL (Network model with more than one cell in any population): HIGH
#  jNeuroML >>      ✓ MULTI_POPULATION_MODEL (Network model with multiple populations of cells): HIGH
#  jNeuroML >>      ✓ NETWORK_WITH_INPUTS_MODEL (Network model with external inputs to cells): HIGH
#  jNeuroML >>      ✓ NETWORK_WITH_PROJECTIONS_MODEL (Network model with projections between populations): HIGH
#  jNeuroML >>      ✓ NETWORK_WITH_GAP_JUNCTIONS_MODEL (Network model with gap junctions/electrical connections between cells): HIGH
#  jNeuroML >>      ✓ NETWORK_WITH_ANALOG_CONNS_MODEL (Network model with analog/continuously communicating connections between cells): HIGH
#  jNeuroML >>      ✓ ABSTRACT_CELL_MODEL (Model with abstract (non conductance based) cell(s)): HIGH
#  jNeuroML >>      ✓ COND_BASED_CELL_MODEL (Model with conductance based cell(s)): HIGH
#  jNeuroML >>      x MULTICOMPARTMENTAL_CELL_MODEL (Model with multicompartmental cell(s)): NONE
#  jNeuroML >>      ✓ CHANNEL_POPULATIONS_CELL_MODEL (Model with channel populations): HIGH
#  jNeuroML >>      x CHANNEL_DENSITY_ON_SEGMENT (Model with channel density specified per segment (aot segmentGroup)): NONE
#  jNeuroML >>      ✓ HH_CHANNEL_MODEL (Model with HH based ion channel(s)): HIGH
#  jNeuroML >>      ✓ KS_CHANNEL_MODEL (Model with kinetic scheme based ion channel(s)): MEDIUM
#  jNeuroML >>
#  jNeuroML >>  	at org.neuroml.export.utils.support.SupportLevelInfo.checkConversionSupported(SupportLevelInfo.java:144)
#  jNeuroML >>  	at org.neuroml.export.utils.Utils.loadLemsFile(Utils.java:526)
#  jNeuroML >>  	at org.neuroml.export.utils.Utils.runLemsFile(Utils.java:493)
#  jNeuroML >>  	at org.neuroml.JNeuroML.main(JNeuroML.java:606)
#  jNeuroML >>  INFO Oct 03,2023 20:14  (INFO) Loading LEMS file from: /home/kedoxey/CRCNS/PyramidalCellSimulations/LEMS_iv_L5PC.xml
#  jNeuroML >>  INFO Oct 03,2023 20:14  (INFO) Reading from: /home/kedoxey/CRCNS/PyramidalCellSimulations/LEMS_iv_L5PC.xml
#  jNeuroML >>  WARNING Oct 03,2023 20:14  (WARNING) Unused attribute in Component(id=CaDynamics_E2_NML2__decay122__gamma5_09Emin4 type=concentrationModelHayEtAl): XMLAttribute(ion, ca)  at: org.lemsml.jlems.core.type.Component.resolve(Component.java:540)
#  jNeuroML >>  WARNING Oct 03,2023 20:14  (WARNING) Unused attribute in Component(id=CaDynamics_E2_NML2__decay460__gamma5_01Emin4 type=concentrationModelHayEtAl): XMLAttribute(ion, ca)  at:
#  jNeuroML >>
# pyNeuroML >>> ERROR - execute_command_in_dir returned with output:  jNeuroML v0.12.0
# Loading: /home/kedoxey/CRCNS/PyramidalCellSimulations/LEMS_iv_L5PC.xml with jLEMS, NO GUI mode...
# org.neuroml.export.exceptions.ModelFeatureSupportException: Feature not supported in LEMS: MULTICOMPARTMENTAL_CELL_MODEL (Model with multicompartmental cell(s))
#     Level of support for MULTICOMPARTMENTAL_CELL_MODEL in LEMS is insufficient: NONE
#
# Info on supported features:
# Format: LEMS
#     ✓ SINGLE_COMP_MODEL (Model with only a single component (no network)): HIGH
#     ✓ NETWORK_MODEL (Network model): HIGH
#     ✓ MULTI_CELL_MODEL (Network model with more than one cell in any population): HIGH
#     ✓ MULTI_POPULATION_MODEL (Network model with multiple populations of cells): HIGH
#     ✓ NETWORK_WITH_INPUTS_MODEL (Network model with external inputs to cells): HIGH
#     ✓ NETWORK_WITH_PROJECTIONS_MODEL (Network model with projections between populations): HIGH
#     ✓ NETWORK_WITH_GAP_JUNCTIONS_MODEL (Network model with gap junctions/electrical connections between cells): HIGH
#     ✓ NETWORK_WITH_ANALOG_CONNS_MODEL (Network model with analog/continuously communicating connections between cells): HIGH
#     ✓ ABSTRACT_CELL_MODEL (Model with abstract (non conductance based) cell(s)): HIGH
#     ✓ COND_BASED_CELL_MODEL (Model with conductance based cell(s)): HIGH
#     x MULTICOMPARTMENTAL_CELL_MODEL (Model with multicompartmental cell(s)): NONE
#     ✓ CHANNEL_POPULATIONS_CELL_MODEL (Model with channel populations): HIGH
#     x CHANNEL_DENSITY_ON_SEGMENT (Model with channel density specified per segment (aot segmentGroup)): NONE
#     ✓ HH_CHANNEL_MODEL (Model with HH based ion channel(s)): HIGH
#     ✓ KS_CHANNEL_MODEL (Model with kinetic scheme based ion channel(s)): MEDIUM
#
# 	at org.neuroml.export.utils.support.SupportLevelInfo.checkConversionSupported(SupportLevelInfo.java:144)
# 	at org.neuroml.export.utils.Utils.loadLemsFile(Utils.java:526)
# 	at org.neuroml.export.utils.Utils.runLemsFile(Utils.java:493)
# 	at org.neuroml.JNeuroML.main(JNeuroML.java:606)
# INFO Oct 03,2023 20:14  (INFO) Loading LEMS file from: /home/kedoxey/CRCNS/PyramidalCellSimulations/LEMS_iv_L5PC.xml
# INFO Oct 03,2023 20:14  (INFO) Reading from: /home/kedoxey/CRCNS/PyramidalCellSimulations/LEMS_iv_L5PC.xml
# WARNING Oct 03,2023 20:14  (WARNING) Unused attribute in Component(id=CaDynamics_E2_NML2__decay122__gamma5_09Emin4 type=concentrationModelHayEtAl): XMLAttribute(ion, ca)  at: org.lemsml.jlems.core.type.Component.resolve(Component.java:540)
# WARNING Oct 03,2023 20:14  (WARNING) Unused attribute in Component(id=CaDynamics_E2_NML2__decay460__gamma5_01Emin4 type=concentrationModelHayEtAl): XMLAttribute(ion, ca)  at:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /home/kedoxey/.conda/envs/OBModel_linux/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3560: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
